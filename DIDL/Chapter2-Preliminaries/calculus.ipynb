# %%
# %%bash
# pip3 install d2l
# Out:
# Collecting d2l
#   Downloading d2l-1.0.3-py3-none-any.whl.metadata (556 bytes)
# Requirement already satisfied: jupyter==1.0.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from d2l) (1.0.0)
# Collecting numpy==1.23.5 (from d2l)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting matplotlib==3.7.2 (from d2l)
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting matplotlib-inline==0.1.6 (from d2l)
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests==2.31.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from d2l) (2.31.0)
# Collecting pandas==2.0.3 (from d2l)
#   Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting scipy==1.10.1 (from d2l)
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.1.3)
# Requirement already satisfied: qtconsole in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (5.5.2)
# Requirement already satisfied: jupyter-console in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.6.3)
# Requirement already satisfied: nbconvert in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (7.16.4)
# Requirement already satisfied: ipykernel in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (6.29.3)
# Requirement already satisfied: ipywidgets in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter==1.0.0->d2l) (8.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (10.3.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib==3.7.2->d2l)
#   Downloading pyparsing-3.0.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib==3.7.2->d2l) (2.9.0)
# Requirement already satisfied: traitlets in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from matplotlib-inline==0.1.6->d2l) (5.14.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from pandas==2.0.3->d2l) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from requests==2.31.0->d2l) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from requests==2.31.0->d2l) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from requests==2.31.0->d2l) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.2->d2l) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.22.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.7.2)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (1.6.0)
# Requirement already satisfied: psutil in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipykernel->jupyter==1.0.0->d2l) (6.4)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipywidgets->jupyter==1.0.0->d2l) (3.0.10)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (3.0.42)
# Requirement already satisfied: pygments in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-console->jupyter==1.0.0->d2l) (2.18.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbconvert->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (2.24.0)
# Requirement already satisfied: jupyterlab<4.2,>=4.1.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (4.1.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from notebook->jupyter==1.0.0->d2l) (0.2.4)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from qtconsole->jupyter==1.0.0->d2l) (2.4.1)
# Requirement already satisfied: webencodings in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert->jupyter==1.0.0->d2l) (0.5.1)
# Requirement already satisfied: decorator in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.19.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.0.0->d2l) (4.2.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.3.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.5.3)
# Requirement already satisfied: overrides in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (7.7.0)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.20.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.18.1)
# Requirement already satisfied: websocket-client in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (2.2.5)
# Requirement already satisfied: tomli>=1.2.2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (2.14.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.9.25)
# Requirement already satisfied: jsonschema>=4.17.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (4.17.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->d2l) (2.19.1)
# Requirement already satisfied: wcwidth in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.0.0->d2l) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->d2l) (2.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.2,>=4.1.1->notebook->jupyter==1.0.0->d2l) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.8.4)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (23.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server<3,>=2.22.1->notebook->jupyter==1.0.0->d2l) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter==1.0.0->d2l) (0.2.2)
# Requirement already satisfied: fqdn in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=3.2.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->d2l) (2.9.0.20240316)
# Downloading d2l-1.0.3-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 9.1 MB/s eta 0:00:00
# Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.7 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 113.4 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 129.7 MB/s eta 0:00:0000:010:01
# Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 80.0 MB/s eta 0:00:00:00:0100:01
# Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 12.7 MB/s eta 0:00:00
# Installing collected packages: pyparsing, numpy, matplotlib-inline, scipy, pandas, matplotlib, d2l
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.2
#     Uninstalling pyparsing-3.1.2:
#       Successfully uninstalled pyparsing-3.1.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.7
#     Uninstalling matplotlib-inline-0.1.7:
#       Successfully uninstalled matplotlib-inline-0.1.7
#   Attempting uninstall: scipy
#     Found existing installation: SciPy 1.11.4
#     Uninstalling SciPy-1.11.4:
#       Successfully uninstalled SciPy-1.11.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-common 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-core 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-core 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-features 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-multimodal 0.8.3 requires pytorch-lightning<1.10.0,>=1.9.0, but you have pytorch-lightning 2.0.9 which is incompatible.
# autogluon-multimodal 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 0.8.3 requires torch<1.14,>=1.9, but you have torch 2.6.0 which is incompatible.
# autogluon-multimodal 0.8.3 requires torchmetrics<0.12.0,>=0.11.0, but you have torchmetrics 1.0.3 which is incompatible.
# autogluon-multimodal 0.8.3 requires torchvision<0.15.0, but you have torchvision 0.15.2a0+ab7b3e6 which is incompatible.
# autogluon-tabular 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-tabular 0.8.3 requires scikit-learn<1.4.1,>=1.1, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 0.8.3 requires pandas<1.6,>=1.4.1, but you have pandas 2.0.3 which is incompatible.
# autogluon-timeseries 0.8.3 requires pytorch-lightning<1.10.0,>=1.7.4, but you have pytorch-lightning 2.0.9 which is incompatible.
# autogluon-timeseries 0.8.3 requires torch<1.14,>=1.9, but you have torch 2.6.0 which is incompatible.
# autovizwidget 0.21.0 requires pandas<2.0.0,>=0.20.1, but you have pandas 2.0.3 which is incompatible.
# fastai 2.7.15 requires torch<2.4,>=1.10, but you have torch 2.6.0 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.0.3 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.0.3 which is incompatible.
# Successfully installed d2l-1.0.3 matplotlib-3.7.2 matplotlib-inline-0.1.6 numpy-1.23.5 pandas-2.0.3 pyparsing-3.0.9 scipy-1.10.1

# %%
# %matplotlib inline
import numpy as np
from matplotlib_inline import backend_inline
from d2l import torch as d2l
# Out:
# /opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/opt/conda/envs/sagemaker-distribution/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
def f(x):
    return 3 * x ** 2 - 4 * x

# %%
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}')
# Out:
# h=0.10000, numerical limit=2.30000
# h=0.01000, numerical limit=2.03000
# h=0.00100, numerical limit=2.00300
# h=0.00010, numerical limit=2.00030
# h=0.00001, numerical limit=2.00003

# %%
np.arange(-1, -6, -1)
# Out:
# array([-1, -2, -3, -4, -5])

# %%
def use_svg_display():  #@save
    """Use the svg format to display a plot in Jupyter."""
    backend_inline.set_matplotlib_formats('svg')

# %%
def set_figsize(figsize=(3.5, 2.5)):  #@save
    """Set the figure size for matplotlib."""
    use_svg_display()
    d2l.plt.rcParams['figure.figsize'] = figsize

# %%
#@save
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """Set the axes for matplotlib."""
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_xscale(xscale)
    axes.set_yscale(yscale)
    axes.set_xlim(xlim)
    axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

# %%
#@save
def plot(X, Y=None, xlabel=None, ylabel=None, legend=[], xlim=None,
         ylim=None, xscale='linear', yscale='linear',
         fmts=('-', 'm--', 'g-.', 'r:'), figsize=(3.5, 2.5), axes=None):
    """Plot data points."""

    def has_one_axis(X):  # True if X (tensor or list) has 1 axis
        return (hasattr(X, "ndim") and X.ndim == 1 or isinstance(X, list)
                and not hasattr(X[0], "__len__"))

    if has_one_axis(X): X = [X]
    if Y is None:
        X, Y = [[]] * len(X), X
    elif has_one_axis(Y):
        Y = [Y]
    if len(X) != len(Y):
        X = X * len(Y)

    set_figsize(figsize)
    if axes is None:
        axes = d2l.plt.gca()
    axes.cla()
    for x, y, fmt in zip(X, Y, fmts):
        axes.plot(x,y,fmt) if len(x) else axes.plot(y,fmt)
    set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend)

# %%
x = np.arange(0, 3, 0.1)
[f(x), 2 * x - 3]
# Out:
# [array([ 0.  , -0.37, -0.68, -0.93, -1.12, -1.25, -1.32, -1.33, -1.28,
#         -1.17, -1.  , -0.77, -0.48, -0.13,  0.28,  0.75,  1.28,  1.87,
#          2.52,  3.23,  4.  ,  4.83,  5.72,  6.67,  7.68,  8.75,  9.88,
#         11.07, 12.32, 13.63]),
#  array([-3. , -2.8, -2.6, -2.4, -2.2, -2. , -1.8, -1.6, -1.4, -1.2, -1. ,
#         -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,
#          1.4,  1.6,  1.8,  2. ,  2.2,  2.4,  2.6,  2.8])]

# %%
plot(x, [f(x), 2 * x - 3], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])
